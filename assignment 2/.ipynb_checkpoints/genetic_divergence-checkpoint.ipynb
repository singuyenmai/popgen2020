# %%
library('diveRsity')
# Out:
# Registered S3 methods overwritten by 'huge':
#   method    from
#   plot.sim  BDgraph
#   print.sim BDgraph

# %%
nu <- diffCalc(infile="soc_np_usats", fst=TRUE, bs_locus=TRUE, boots=2000, ci_type="loci")
nu
# Out:
# $std_stats
#           loci    gst    Gst   GGst      D     Fis    Fst    Fit
# 1        EV001 0.2200 0.8100 0.8443 0.7564  0.0179 0.5110 0.5198
# 2        EV037 0.0488 0.5219 0.5442 0.4974  0.1023 0.0990 0.1912
# 3        EV094 0.1157 0.5695 0.6141 0.5132  0.0068 0.2757 0.2806
# 4      GATA028 0.0592 0.4347 0.4663 0.3991  0.0109 0.1239 0.1334
# 5      GATA053 0.2367 0.7509 0.7986 0.6737  0.2471 0.6014 0.6999
# 6      GATA098 0.0086 0.0314 0.0397 0.0230  0.1421 0.0193 0.1587
# 7    GATA25072 0.0450 0.1916 0.2265 0.1535  0.0063 0.1139 0.1195
# 8      GATA417 0.0190 0.2368 0.2511 0.2221  0.0210 0.0395 0.0597
# 9    GATA43950 0.0528 0.3560 0.3883 0.3202 -0.0153 0.0992 0.0853
# 10 GATA6063862 0.0639 0.3551 0.3938 0.3111 -0.0281 0.1411 0.1170
# 11     GGAA520 0.2116 0.8038 0.8381 0.7512  0.0209 0.5096 0.5198
# 12       GT011 0.1118 0.5646 0.6084 0.5099 -0.0370 0.2495 0.2217
# 13       GT023 0.0666 0.4351 0.4703 0.3948 -0.0147 0.1423 0.1297
# ...

# %%
mt <- haploDiv(infile="soc_np_mtdna", boots=2000, pairwise=T)
mt
# Out:
# $locus
# [1] 0.5902
#
# $overall
# [1] 0.5902
#
# $pairwise
#           NP025001 SC005129
# NP025001        NA       NA
# SC005129 0.5902024       NA
#
# $bs_pairwise
#                          actual      mean   BC_mean Lower_95%CI Upper_95%CI
# NP025001 vs. SC005129 0.5902024 0.5986516 0.5902024   0.4362904    0.730823
#                       BC_Lower_95%CI BC_Upper_95%CI
# NP025001 vs. SC005129      0.4278412      0.7223738

# %%
divBasic(infile="soc_np_usats")$He
# Out:
#             NP025001 SC005129
# EV001       0.88     0.26
# EV037       0.88     0.76
# EV094       0.89     0.42
# GATA028     0.84     0.66
# GATA053     0.88     0.15
# GATA098     0.64     0.49
# GATA25072   0.79     0.43
# GATA417     0.89     0.80
# GATA43950   0.72     0.75
# GATA6063862 0.81     0.56
# GGAA520     0.91     0.25
# GT011       0.85     0.48
# GT023       0.84     0.62
# GT195       0.84     0.70
# GT211       0.85     0.48
# GT271       0.76     0.42
# GT575       0.50     0.08
# TAA023      0.79     0.54
# overall     0.81     0.49
